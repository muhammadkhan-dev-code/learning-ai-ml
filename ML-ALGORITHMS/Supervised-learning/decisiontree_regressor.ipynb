# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split

# %%
df= load_diabetes(as_frame=True).frame  
df.head()

# %%
X = df.drop("target",axis=1)
y= df['target']

# %%
X_train,X_test,y_train,y_test= train_test_split(
    X,y,test_size=0.3,random_state=42
)

# %%
from sklearn.tree import  DecisionTreeRegressor

model= DecisionTreeRegressor()
model.fit(X_train,y_train)

# %% [markdown]
# ## good example of extreme overfitting

# %%
from sklearn.metrics import r2_score,mean_squared_error

y_pred_train= model.predict(X_train)
y_pred_test= model.predict(X_test)

print(f"MSE FOR TRAINING : {mean_squared_error(y_train,y_pred_train)}")
print(f"MSE FOR TESTIING : {mean_squared_error(y_test,y_pred_test)}")

print(f"R^2 FOR TRAINING : {r2_score(y_train,y_pred_train)}")
print(f"R^@ FOR TESTING : {r2_score(y_test,y_pred_test)}")

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(18,12))

plot_tree(
    model,
    feature_names=X.columns,
    filled=True,
    max_depth=2
)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##  Prepruning because our dataset is small

# %%
from sklearn.tree import  DecisionTreeRegressor

model= DecisionTreeRegressor(max_depth=7, min_samples_leaf=20)
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=7, min_samples_leaf=20)

# %%
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

y_pred_train= model.predict(X_train)
y_pred_test= model.predict(X_test)

print(f"MSE FOR TRAINING : {mean_squared_error(y_train,y_pred_train)}")
print(f"MSE FOR TESTIING : {mean_squared_error(y_test,y_pred_test)}")

print(f"R^2 FOR TRAINING : {r2_score(y_train,y_pred_train)}")
print(f"R^@ FOR TESTING : {r2_score(y_test,y_pred_test)}")



plt.figure(figsize=(18,12))

plot_tree(
    model,
    feature_names=X.columns,
    filled=True,

)
plt.tight_layout()
plt.show()
# Out:
# MSE FOR TRAINING : 2795.7093704335157
# MSE FOR TESTIING : 3177.664925233041
# R^2 FOR TRAINING : 0.5452860742356658
# R^@ FOR TESTING : 0.41135906558189406

# %%
# DECISION TREE REGRESSION
# USE BAGGING REGRESSIOR HW
