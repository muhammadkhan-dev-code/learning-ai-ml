# %%
import pandas as pd
import seaborn as sns

# %%
insurance_data= pd.read_csv("insurance.csv")

# %%
# visulize 
sns.scatterplot(x=insurance_data["bmi"],y=insurance_data["charges"],hue=insurance_data["smoker"])

# %%
x=insurance_data.drop(columns=["charges",'region'])
y=insurance_data['charges']

 # encoding the values sex m=1, f=0
x['sex']=x['sex'].map({'male':1,'female':0})
x['smoker']=x['smoker'].map({'yes':1,'no':0})

encoded_data = x.copy()
encoded_data['charges'] = y
encoded_data.to_csv("encoded_data.csv", index=False)

# %%
# Train & Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.20, random_state=42)

# %%
# Train the model
from sklearn.linear_model import LinearRegression

model=LinearRegression()

model.fit(X_train,y_train)

# %%
# Predict Values
y_predict=model.predict(X_test)

# %%
# Evaluate  dealing with test data

from sklearn.metrics import r2_score

r2=r2_score(y_test,y_predict)

print('r2 squared value',r2)

n= X_test.shape[0]
p= X_test.shape[1]

adjusted_r2= 1- ((1-r2)*(n-1)/(n-p-1))

print('Adjusted r2 squared value',adjusted_r2)
# Out:
# r2 squared value 0.7811302113434095
# Adjusted r2 squared value 0.7769533069797342
